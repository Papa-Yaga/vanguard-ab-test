# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %matplotlib inline

# %%
c = pd.read_csv("C:/Users/atakp/Documents/GitHub/vanguard-ab-test/all_data.csv")
clients_profile_df
# Out:
# C:\Users\atakp\AppData\Local\Temp\ipykernel_21844\2952541807.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   clients_profile_df = pd.read_csv("C:/Users/atakp/Documents/GitHub/vanguard-ab-test/all_data.csv")
#         Unnamed: 0  client_id             visitor_id  \
# 0                0    9988021   580560515_7732621733
# 1                1    9988021   580560515_7732621733
# 2                2    9988021   580560515_7732621733
# 3                3    9988021   580560515_7732621733
# 4                4    9988021   580560515_7732621733
# ...            ...        ...                    ...
# 449826      449826    9895983  473024645_56027518531
# 449827      449827    9895983  473024645_56027518531
# 449828      449828    9895983  473024645_56027518531
# 449829      449829    9895983  473024645_56027518531
# 449830      449830    9895983  473024645_56027518531
#
# ...

# %%
#Who are the primary clients using this online process?
# Count of clients by age group
age_counts = clients_profile_df['clnt_age'].value_counts()

# Count of clients by gender
gender_counts = clients_profile_df['gendr'].value_counts()

# Count of clients by tenure year
tenure_counts = clients_profile_df['clnt_tenure_yr'].value_counts()

age_counts, gender_counts, tenure_counts
# Out:
# (clnt_age
#  58.5    6432
#  57.5    6115
#  52.5    6061
#  59.5    6037
#  55.5    5913
#          ...
#  96.0      10
#  14.0      10
#  13.5       9
#  95.5       6
#  94.5       5
#  Name: count, Length: 165, dtype: int64,
#  gendr
#  M    151877
#  U    151608
#  F    146217
#  X        14
#  Name: count, dtype: int64,
#  clnt_tenure_yr
#  6.0     44377
#  5.0     44121
#  7.0     31347
#  4.0     28956
#  15.0    28679
#  8.0     25067
#  14.0    22995
#  12.0    22654
#  13.0    22646
#  9.0     21057
#  11.0    18111
#  10.0    17599
#  16.0    16990
#  21.0    15037
#  20.0    10616
#  22.0     9726
#  17.0     8870
#  23.0     8651
#  18.0     7741
#  19.0     7709
#  24.0     6040
#  26.0     4450
#  27.0     4438
#  28.0     3345
#  25.0     3319
#  3.0      3021
#  30.0     2265
#  29.0     2020
#  33.0     1554
#  32.0     1377
#  34.0     1253
#  31.0     1139
#  35.0      743
#  2.0       503
#  36.0      286
#  37.0      225
#  38.0      191
#  48.0      101
# ...

# %%
sns.barplot(data=clients_profile_df, x="clnt_age", y="gendr", palette="coolwarm")
# Out:
# <Axes: xlabel='clnt_age', ylabel='gendr'>

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.barplot(x=age_counts.index, y=age_counts.values, palette='viridis')
plt.title('Clients by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')

plt.subplot(1, 3, 2)
sns.barplot(x=gender_counts.index, y=gender_counts.values, palette='viridis')
plt.title('Clients by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.subplot(1, 3, 3)
sns.barplot(x=tenure_counts.index, y=tenure_counts.values, palette='viridis')
plt.title('Clients by Tenure')
plt.xlabel('Tenure')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
#are the primary clients older or younger 
# Distribution of client age
plt.figure(figsize=(10, 5))
sns.histplot(clients_profile_df['clnt_age'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Client Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#are the primary clients new or old
# Distribution of client tenure year
plt.figure(figsize=(10, 5))
sns.histplot(clients_profile_df['clnt_tenure_yr'], bins=20, kde=True, color='blue')
plt.title('Distribution of Client Tenure')
plt.xlabel('Tenure (Year)')
plt.ylabel('Count')
plt.show()

# %%
# Distribution of client tenure month
plt.figure(figsize=(10, 5))
sns.histplot(clients_profile_df['clnt_tenure_mnth'], bins=20, kde=True, palette="coolwarm")
plt.title('Distribution of Client Tenure')
plt.xlabel('Tenure (Year)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\atakp\AppData\Local\Temp\ipykernel_21844\3747076729.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(clients_profile_df['clnt_tenure_mnth'], bins=20, kde=True, palette="coolwarm")

# %%
# Analyze engagement
# Calculate engagement on the platform
avg_engagement = clients_profile_df.groupby('client_id')['logons_6_mnth'].mean()
avg_engagement
# Out:
# client_id
# 169        4.0
# 555        6.0
# 647        4.0
# 722        1.0
# 934        3.0
#           ...
# 9999400    3.0
# 9999626    9.0
# 9999729    9.0
# 9999832    4.0
# 9999839    3.0
# Name: logons_6_mnth, Length: 70609, dtype: float64

# %%
# Visualize average engagement distribution
plt.figure(figsize=(10, 5))
sns.histplot(avg_engagement , bins=20, kde=True, palette="Set3")
# Out:
# C:\Users\atakp\AppData\Local\Temp\ipykernel_21844\2807769484.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(avg_engagement , bins=20, kde=True, palette="Set3")
# <Axes: xlabel='logons_6_mnth', ylabel='Count'>
